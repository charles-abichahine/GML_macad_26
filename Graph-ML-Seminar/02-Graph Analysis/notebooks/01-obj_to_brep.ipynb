# %% [markdown]
# # OBJ to BREP

# %%
from topologicpy.Topology import Topology
from topologicpy.Cluster  import Cluster

OBJ_PATH  = r"C:\Users\charl\Desktop\iaac\MaCad\01-year-I\03-module-3\aia26 - s.3 graph ml\GML_macad_26\Graph-ML-Seminar\Assignment-02\assets\courthouse-plan.obj"
BREP_PATH = r"C:\Users\charl\Desktop\iaac\MaCad\01-year-I\03-module-3\aia26 - s.3 graph ml\GML_macad_26\Graph-ML-Seminar\Assignment-02\assets\courthouse-plan.brep"

topo = Topology.ByOBJPath(OBJ_PATH)
if isinstance(topo, list):
    topo = Cluster.ByTopologies(topo)

print("Type:", Topology.TypeAsString(topo), "Faces:", len(Topology.Faces(topo)))

ok = Topology.ExportToBREP(topo, path=BREP_PATH, overwrite=True)
print("Exported:", ok)

# %%
from topologicpy.Topology import Topology
from topologicpy.Cluster  import Cluster
from topologicpy.Shell    import Shell
from topologicpy.Face     import Face

BREP_IN  = r"C:\Users\charl\Desktop\iaac\MaCad\01-year-I\03-module-3\aia26 - s.3 graph ml\GML_macad_26\Graph-ML-Seminar\Assignment-02\assets\courthouse-plan.brep"
BREP_OUT = r"C:\Users\charl\Desktop\iaac\MaCad\01-year-I\03-module-3\aia26 - s.3 graph ml\GML_macad_26\Graph-ML-Seminar\Assignment-02\assets\courthouse-plan_face.brep"

floor_plan = Topology.ByBREPPath(BREP_IN)
print("Loaded:", floor_plan)

triangles = Cluster.Faces(floor_plan)
shell     = Shell.ByFaces(triangles)
eb        = Shell.ExternalBoundary(shell)
ib_list   = Shell.InternalBoundaries(shell)
new_face  = Face.ByWires(eb, ib_list)
new_face  = Topology.RemoveCollinearEdges(new_face)

print(f"Final edge count: {len(Topology.Edges(new_face))}")
print(new_face)

Topology.Show(new_face)
Topology.ExportToBREP(new_face, path=BREP_OUT, overwrite=True)
